# %%
import numpy as np
import pandas as pd

# %%
jai = pd.read_csv('https://raw.githubusercontent.com/training-ml/Files/main/Sales_LinReg.csv')

# %%
jai
# Out:
#      Republic  NDTV   TV5   TV9  AajTak  sales
# 0         8.7  48.9   4.0  75.0    49.0    7.2
# 1        57.5  32.8  65.9  23.5    57.5   11.8
# 2       120.2  19.6   7.2  11.6    18.5   13.2
# 3         8.6   2.1  46.0   1.0     2.6    4.8
# 4       199.8   2.6  52.9  21.2     2.9   10.6
# ..        ...   ...   ...   ...     ...    ...
# 300     286.0  13.9  35.2   3.7    13.9   15.9
# 301      18.7  12.1  23.7  23.4    18.7    6.7
# 302      39.5  41.1  17.6   5.8    39.5   10.8
# 303      75.5  10.8   8.3   6.0    75.5    9.9
# 304      17.2   4.1  30.0  31.6    17.2    5.9
#
# [305 rows x 6 columns]

# %%
jai.head()
# Out:
#    Republic  NDTV   TV5   TV9  AajTak  sales
# 0       8.7  48.9   4.0  75.0    49.0    7.2
# 1      57.5  32.8  65.9  23.5    57.5   11.8
# 2     120.2  19.6   7.2  11.6    18.5   13.2
# 3       8.6   2.1  46.0   1.0     2.6    4.8
# 4     199.8   2.6  52.9  21.2     2.9   10.6

# %%
atbcl = pd.read_csv("C:\\Users\MIS\ Fastag data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 atbcl = pd.read_csv("C:\\Users\MIS\ Fastag data.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
jai.tail()
# Out:
#      Republic  NDTV   TV5   TV9  AajTak  sales
# 300     286.0  13.9  35.2   3.7    13.9   15.9
# 301      18.7  12.1  23.7  23.4    18.7    6.7
# 302      39.5  41.1  17.6   5.8    39.5   10.8
# 303      75.5  10.8   8.3   6.0    75.5    9.9
# 304      17.2   4.1  30.0  31.6    17.2    5.9

# %%
jai.head()
# Out:
#    Republic  NDTV   TV5   TV9  AajTak  sales
# 0       8.7  48.9   4.0  75.0    49.0    7.2
# 1      57.5  32.8  65.9  23.5    57.5   11.8
# 2     120.2  19.6   7.2  11.6    18.5   13.2
# 3       8.6   2.1  46.0   1.0     2.6    4.8
# 4     199.8   2.6  52.9  21.2     2.9   10.6

# %%
jai.sample(7)
# Out:
#      Republic  NDTV   TV5   TV9  AajTak  sales
# 264     215.4  23.6  24.3  57.6    23.6   17.1
# 36      177.0  33.4  31.5  38.7    33.4   17.1
# 262      17.9  37.6   5.7  21.6    37.6    8.0
# 288      17.2   4.1  30.0  31.6     4.1    5.9
# 268      19.6  20.1  49.3  17.0    20.1    7.6
# 51       69.0   9.3  31.7   0.9     9.3    9.3
# 146       NaN  18.1  23.1  30.7    18.1   14.4

# %% [markdown]
# # pd.set_option['display.max_row',None]

# %%
jai.shape
# Out:
# (305, 6)

# %%
type(jai)
# Out:
# pandas.core.frame.DataFrame

# %%
atbcl = pd.read_excel(r"G:\DAILY & MONTHLY REPORT\TBR-2024\TBR January-24\ Shift_Wise_Report January 2024 N.xlsx " ,
                     sheet_name='Summary Report')
atbcl
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 atbcl = pd.read_excel(r"G:\DAILY & MONTHLY REPORT\TBR-2024\TBR January-24\ Shift_Wise_Report January 2024 N.xlsx " ,
#       2                      sheet_name='Summary Report')
#       3 atbcl
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
# ...

# %%
atbcl = pd.read_excel(r"C:\Users\MIS\Shift_Wise_Report January 2024 N.xlsx " ,
                     sheet_name='Summary Report')
atbcl
# Out:
#              Unnamed: 0                               Unnamed: 1 Unnamed: 2  \
# 0                   NaN        ADITYAPUR TOLL BRIDGE COMPANY LTD        NaN
# 1                   NaN                                      NaN        NaN
# 2                   NaN  Summary Sheet for the Month of Jan_2024        NaN
# 3                   NaN                                      NaN        NaN
# 4           Grand Total                                      NaN      87926
# 5                   NaN                                      NaN        NaN
# 6                  Date                                      Day        Car
# 7                   NaN                                      NaN        NaN
# 8   2024-01-01 00:00:00                                   Monday       2440
# 9   2024-01-02 00:00:00                                  Tuesday       2906
# 10  2024-01-03 00:00:00                                Wednesday       2790
# ...

# %%
atbcl.head()
# Out:
#     Unnamed: 0                               Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0          NaN        ADITYAPUR TOLL BRIDGE COMPANY LTD        NaN        NaN
# 1          NaN                                      NaN        NaN        NaN
# 2          NaN  Summary Sheet for the Month of Jan_2024        NaN        NaN
# 3          NaN                                      NaN        NaN        NaN
# 4  Grand Total                                      NaN      87926      13009
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4       6770      43083         65     150853    6676065     161880
#
#   Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13
# ...

# %%
atbcl.tail()
# Out:
#              Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 34  2024-01-27 00:00:00   Saturday       3119        514        276
# 35  2024-01-28 00:00:00     Sunday       2595        304        144
# 36  2024-01-29 00:00:00     Monday       3042        484        248
# 37  2024-01-30 00:00:00    Tuesday       3278        527        261
# 38  2024-01-31 00:00:00  Wednesday       3229        539        251
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 34       1490          3       5402     237145       6065      159465
# 35       1181          3       4227     182820       3140      129655
# 36       1537          1       5312     237035       6490      166320
# 37       1633          4       5703     251885       4890      177745
# 38       1739          9       5767     262865       6900      181490
#
#    Unnamed: 11 Unnamed: 12 Unnamed: 13
# 34           0       71615           0
# 35           0       50025           0
# ...

# %%
atbcl.shape
# Out:
# (39, 14)
