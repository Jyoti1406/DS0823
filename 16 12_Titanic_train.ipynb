# %% [markdown]
# # Data Manipulation

# %%
import pandas as pd
import numpy as np

# %%
titanic_train = pd.read_csv("https://raw.githubusercontent.com/training-ml/Files/main/titanic_train.csv")

# %%
titanic_train.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            4         1       1
# 4           4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
# titanic_train.drop(["Unnamed: 0"] , axis=1 , inplace=True)

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# how to check unique values of any column

# %%
titanic_train['Survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
# Check unique value counts

titanic_train['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
# titanic_train['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
# How to replace categories using pandas method

# %%
titanic_train['Survived'].replace({0:'Died', 1:'Survived'} , inplace=True)

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1      Died       3
# 1            2  Survived       1
# 2            3  Survived       3
# 3            4  Survived       1
# 4            5      Died       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_train['SibSp'].unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8], dtype=int64)

# %%
titanic_train['SibSp'].replace({0:'Parrents', 1:'Spouse', 3:'Child', 4:'Husband' ,5:'Captain',8:'Staff'},inplace=True)

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1      Died       3
# 1            2  Survived       1
# 2            3  Survived       3
# 3            4  Survived       1
# 4            5      Died       3
#
#                                                 Name     Sex   Age     SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0    Spouse
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    Spouse
# 2                             Heikkinen, Miss. Laina  female  26.0  Parrents
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    Spouse
# 4                           Allen, Mr. William Henry    male  35.0  Parrents
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
# titanic_train['Embarked'].replace({ 'C':'Cherbourg'} , inplace=True )

# %%
# titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1      Died       3
# 1            2  Survived       1
# 2            3  Survived       3
# 3            4  Survived       1
# 4            5      Died       3
#
#                                                 Name     Sex   Age     SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0    Spouse
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    Spouse
# 2                             Heikkinen, Miss. Laina  female  26.0  Parrents
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    Spouse
# 4                           Allen, Mr. William Henry    male  35.0  Parrents
#
#    Parch            Ticket     Fare Cabin   Embarked
# 0      0         A/5 21171   7.2500   NaN          S
# 1      0          PC 17599  71.2833   C85  Cherbourg
# 2      0  STON/O2. 3101282   7.9250   NaN          S
# 3      0            113803  53.1000  C123          S
# ...

# %%
# titanic_train['Embarked'].replace({ 'Cherbourg': 'C'} , inplace=True )

# %%
# titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1      Died       3
# 1            2  Survived       1
# 2            3  Survived       3
# 3            4  Survived       1
# 4            5      Died       3
#
#                                                 Name     Sex   Age     SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0    Spouse
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    Spouse
# 2                             Heikkinen, Miss. Laina  female  26.0  Parrents
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    Spouse
# 4                           Allen, Mr. William Henry    male  35.0  Parrents
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
dd_sv_cnt = pd.crosstab(titanic_train['Survived'], titanic_train['Sex'],margins=True)
dd_sv_cnt
# Out:
# Sex       female  male  All
# Survived
# 0             81   468  549
# 1            233   109  342
# All          314   577  891

# %%
# Check null count in every column
titanic_train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# find all passenger whose age is missing

age_missing = titanic_train[titanic_train['Age'].isna()]

# %%
age_missing
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6      Died       3                          Moran, Mr. James
# 17            18  Survived       2              Williams, Mr. Charles Eugene
# 19            20  Survived       3                   Masselmani, Mrs. Fatima
# 26            27      Died       3                   Emir, Mr. Farred Chehab
# 28            29  Survived       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860      Died       3                          Razi, Mr. Raihed
# 863          864      Died       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869      Died       3               van Melkebeke, Mr. Philemon
# 878          879      Died       3                        Laleff, Mr. Kristo
# 888          889      Died       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
# Find all the passangers who's age is present in the dataset( Equal to NOT IN)

# %%
with_age = titanic_train[titanic_train['Age'].notnull()]

# %%
with_age
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1      Died       3
# 1              2  Survived       1
# 2              3  Survived       3
# 3              4  Survived       1
# 4              5      Died       3
# ..           ...       ...     ...
# 885          886      Died       3
# 886          887      Died       2
# 887          888  Survived       1
# 889          890  Survived       1
# 890          891      Died       3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %% [markdown]
# # whose age is =35,

# %%
age_under = titanic_train[titanic_train.Age.isin([35])]

# %%
age_under
# Out:
#      PassengerId  Survived  Pclass  \
# 3              4  Survived       1
# 4              5      Died       3
# 20            21      Died       2
# 211          212  Survived       2
# 230          231  Survived       1
# 258          259  Survived       1
# 269          270  Survived       1
# 279          280  Survived       3
# 363          364      Died       3
# 383          384  Survived       1
# 486          487  Survived       1
# 590          591      Died       3
# 604          605  Survived       1
# 614          615      Died       3
# 701          702  Survived       1
# 737          738  Survived       1
# 812          813      Died       2
# 847          848      Died       3
#
#                                                   Name     Sex   Age  \
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# 20                                Fynney, Mr. Joseph J    male  35.0
# ...

# %% [markdown]
# # find the maximum fare

# %%
max(titanic_train['Fare'])
# Out:
# 512.3292

# %%
max_ = titanic_train[titanic_train.Fare == max(titanic_train['Fare'])]
max_
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259  Survived       1                    Ward, Miss. Anna
# 679          680  Survived       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738  Survived       1              Lesurer, Mr. Gustave J
#
#         Sex   Age     SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0  Parrents      0  PC 17755  512.3292          NaN        C
# 679    male  36.0  Parrents      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0  Parrents      0  PC 17755  512.3292         B101        C

# %% [markdown]
# # Multiple conditions

# %%
class_female = titanic_train[titanic_train.Pclass.isin([1]) & titanic_train.Sex.isin(['female'])]
class_female
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2  Survived       1
# 3              4  Survived       1
# 11            12  Survived       1
# 31            32  Survived       1
# 52            53  Survived       1
# ..           ...       ...     ...
# 856          857  Survived       1
# 862          863  Survived       1
# 871          872  Survived       1
# 879          880  Survived       1
# 887          888  Survived       1
#
#                                                   Name     Sex   Age  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 11                            Bonnell, Miss. Elizabeth  female  58.0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0
# ..                                                 ...     ...   ...
# ...

# %%
name_age = titanic_train.query('Age > 25 and Name.str.contains("Harris") and Sex ==("male")', engine='python')   #python syntex
name_age
# Out:
#      PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 62            63      Died       1  Harris, Mr. Henry Birkhardt  male  45.0
# 219          220      Died       2           Harris, Mr. Walter  male  30.0
# 263          264      Died       1        Harrison, Mr. William  male  40.0
# 570          571  Survived       2           Harris, Mr. George  male  62.0
#
#         SibSp  Parch       Ticket    Fare Cabin Embarked
# 62     Spouse      0        36973  83.475   C83        S
# 219  Parrents      0    W/C 14208  10.500   NaN        S
# 263  Parrents      0       112059   0.000   B94        S
# 570  Parrents      0  S.W./PP 752  10.500   NaN        S
